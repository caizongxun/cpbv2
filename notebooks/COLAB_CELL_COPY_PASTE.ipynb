# %% [markdown]
# # CPB Trading V3 Model Training
#
# 一鍵訓練並上傳到 HuggingFace & GitHub
#
# - 支持 20 種加密貨幣
# - 自動上傳到 HuggingFace 和 GitHub
# - 訓練時間: ~20-30 分鐘 (GPU)

# %%
import urllib.request
import os

# 下載最新的訓練腳本
print("[*] 正在下載 V3 訓練腳本...")
urllib.request.urlretrieve(
    'https://raw.githubusercontent.com/caizongxun/cpbv2/main/notebooks/V3_TRAINING_CELL_AUTO_UPLOAD.py',
    'v3_training.py'
)

print("[+] 下載完成!")
print("\n[*] 開始執行訓練...\n")

# 執行訓練 (自動包含所有步驟)
exec(open('v3_training.py').read())
