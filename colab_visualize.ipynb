# %% [markdown]
# # CPB v4 Model Prediction Visualizer
#
# Interactive visualization of all 40 trained Transformer models
# - 20 cryptocurrencies
# - 2 timeframes (15m, 1h)
# - Real vs Predicted price comparison

# %%
# Install dependencies
# !pip install -q torch plotly huggingface-hub yfinance pandas numpy

# %%
import os
os.system('curl -sS -o /content/visualize.py https://raw.githubusercontent.com/caizongxun/cpbv2/main/visualize_predictions.py')
print('Script downloaded')

# %%
# Run visualization
# %cd /content
# !python visualize.py

# %%
# Display the HTML visualization
from IPython.display import IFrame
IFrame(src='/content/cpb_predictions_visualization.html', width=1400, height=1600)

# %%
# Download visualization file
from google.colab import files
files.download('/content/cpb_predictions_visualization.html')
